# %%
import requests

# %%
NOTION_API_URL = "https://api.notion.com/v1/pages"
NOTION_API_KEY = "secret_3lW3pscXNMTLyVt8ucguorEg8Zrtld5rOo04jLOD43o"
DATABASE_ID_REP_TRAITE = "6fb0749269924363afa68bd3fab90fa2"

def add_to_notion(data):
    headers = {
        "Authorization": f"Bearer {NOTION_API_KEY}",
        "Content-Type": "application/json",
        "Notion-Version": "2022-06-28"
    }

    payload = {
        "parent": {"database_id": DATABASE_ID_REP_TRAITE},
        "properties": {
            k: {"rich_text": [{"text": {"content": str(data[k])}}]} for k in data.keys()
        }
    }
    print(payload)

    requests.post(NOTION_API_URL, json=payload, headers=headers)

# %%
DATABASE_ID_DATA_BRUT = "d6e83d295d2c40548fdc0fa0241a24c4"

def get_form_rep_from_notion():
    NOTION_QUERY_URL = f"https://api.notion.com/v1/databases/{DATABASE_ID_DATA_BRUT}/query"
    headers = {
        "Authorization": f"Bearer {NOTION_API_KEY}",
        "Content-Type": "application/json",
        "Notion-Version": "2022-06-28"
    }

    response = requests.post(NOTION_QUERY_URL, headers=headers)
    data = response.json()

    rows = []
    for result in data['results']:
        properties = result['properties']
        en_tant_que = properties['Rep1']['rich_text'][0]['text']['content']
        jaimerais = properties['Rep2']['rich_text'][0]['text']['content']
        afin_de_parce_que = properties['Rep3']['rich_text'][0]['text']['content']
        rows.append([en_tant_que, jaimerais, afin_de_parce_que])

    return rows

# %%
get_form_rep_from_notion()
# Out:
# [['Artisans', 'blabla', 'pk'],
#  ['Artisans', 'fabriquer plus de pots', "j'aime bien la poterie"],
#  ['Exploitants agricoles',
#   "plus d'accès à l'eau",
#   'je suis contre les méga bassines'],
#  ['aa', 'aa', 'aa'],
#  ['bb', 'nn', 'bb'],
#  ['aa', 'aa', 'aa'],
#  ['étudiante', 'manger plus', 'en bonne santée'],
#  ['stagaire', 'avoir un meilleur salaire', 'de vivre mieux'],
#  ['retraité',
#   'prendre des cours de cuisine',
#   'pour apprendre de nouvelles recettes'],
#  ['étudiant',
#   "participer à un programme d'échange à l'étranger",
#   'pour découvrir de nouvelles cultures'],
#  ['entrepreneur',
#   'obtenir un prêt pour développer mon entreprise',
#   'pour investir dans de nouveaux projets'],
#  ['ouvrier',
#   'trouver un emploi dans un secteur en croissance',
#   'pour assurer la stabilité financière de ma famille'],
#  ['journaliste',
#   "réaliser un reportage sur un sujet d'actualité",
#   'pour informer le public'],
#  ['professeur',
#   'mettre en place des activités pédagogiques innovantes',
#   'pour motiver mes élèves'],
#  ['retraité',
#   'faire du bénévolat dans ma communauté',
#   'pour aider les personnes dans le besoin'],
#  ['étudiant',
#   "trouver un mentor dans mon domaine d'études",
#   'pour obtenir des conseils professionnels'],
#  ['architecte',
#   'concevoir un bâtiment écologique',
#   "pour préserver l'environnement"],
#  ['ouvrier',
#   'améliorer mes compétences en gestion du temps',
#   'pour être plus efficace au travail'],
#  ['entrepreneur',
#   'développer un nouveau produit innovant',
#   'pour répondre aux besoins du marché'],
#  ['professeur',
#   'organiser un événement culturel dans mon école',
#   'pour enrichir le programme scolaire'],
#  ['retraité',
#   'apprendre une nouvelle langue',
#   'pour voyager dans des pays étrangers'],
#  ['étudiant', 'trouver un emploi à temps partiel', 'pour financer mes études'],
#  ['chercheur',
#   'publier un article dans une revue scientifique renommée',
#   "pour contribuer à l'avancement de la recherche"],
#  ['ouvrier',
#   'améliorer mes compétences en communication',
#   'pour mieux travailler en équipe'],
#  ['cadre', 'obtenir une promotion', 'pour obtenir plus de responsabilités'],
#  ['artisan',
#   'ouvrir ma propre boutique',
#   'pour réaliser mon rêve de devenir indépendant'],
#  ['retraité',
#   "apprendre à jouer d'un nouvel instrument de musique",
#   'pour rester actif mentalement'],
#  ['étudiant',
#   'trouver un logement abordable',
#   'pour vivre de manière autonome'],
#  ['entrepreneur', 'élargir ma clientèle', 'pour développer mon entreprise'],
#  ['chauffeur de taxi',
#   'acheter un nouveau véhicule',
#   'pour améliorer le confort des clients'],
#  ['artiste',
#   "participer à un concours d'art",
#   'pour gagner en reconnaissance'],
#  ['informaticien',
#   'apprendre un nouveau langage de programmation',
#   'pour rester à jour avec les technologies émergentes'],
#  ['infirmier',
#   'trouver un nouvel emploi dans un hôpital mieux équipé',
#   'pour offrir de meilleurs soins aux patients'],
#  ['enseignant',
#   'mettre en place de nouveaux programmes scolaires',
#   "pour améliorer l'éducation des élèves"],
#  ['retraité',
#   'passer plus de temps avec ma famille',
#   'pour renforcer les liens familiaux'],
#  ['étudiant',
#   'trouver un stage dans une entreprise prestigieuse',
#   "pour acquérir de l'expérience professionnelle"],
#  ['pompier',
#   'améliorer les équipements de lutte contre les incendies',
#   'pour protéger la population'],
#  ['vendeur', 'atteindre mes objectifs de vente', 'pour obtenir une prime'],
#  ['avocat',
#   'réussir mon prochain procès',
#   'pour obtenir justice pour mon client'],
#  ['artiste',
#   'organiser une exposition de mes œuvres',
#   'pour partager ma passion avec le public'],
#  ["chef d'entreprise",
#   'augmenter les ventes',
#   'pour assurer la croissance de mon entreprise'],
#  ['ingénieur',
#   'développer de nouvelles compétences',
#   'pour progresser dans ma carrière'],
#  ['ouvrier',
#   'trouver un emploi plus stable',
#   'pour assurer la sécurité financière de ma famille'],
#  ['médecin',
#   'avoir de meilleures conditions de travail',
#   'pour offrir de meilleurs soins aux patients'],
#  ['professeur',
#   'obtenir une augmentation de salaire',
#   'pour mon travail acharné'],
#  ['retraité', 'partir en vacances', 'profiter de ma retraite'],
#  ['étudiant',
#   'avoir plus de temps libre',
#   'pour me concentrer sur mes études'],
#  ['étudiant',
#   'avoir plus de temps libre',
#   'pour me concentrer sur mes études']]
